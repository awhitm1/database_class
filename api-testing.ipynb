# %%
import os
import requests
from dotenv import dotenv_values
from movie_api import *
from dbo import *

# base_url = "https://pokeapi.co/api/v2"
# base_url = "https://api.themoviedb.org/3/movie"

# Load environment variables from .env file
# TMDB_BEARER_TOKEN, TMDB_API_KEY, DB_USER, DB_PASSWORD, DB_HOST, DB_PORT, DB_NAME = dotenv_values(".env").values()
# Out:
# Inserted 0 rows into the database.

# %%
# headers = {
#     "Authorization": f"Bearer {TMDB_BEARER_TOKEN}",
#     "Content-Type": "application/json"
# }
# response = requests.get(f"{base_url}/popular", headers=headers)

# if response.status_code == 200:
#     data = response.json()
#     print("data:", data)
#     print(data["results"][0])

# print(f"Status Code: {response.status_code}")

# %%
execute_query("SELECT * FROM movies;")
# Out:
# d:\databaseClass\database_class\dbo.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, conn, index_col='tmdb_id')
#                               poster_path  \
# tmdb_id
# 170      /sQckQRt17VaWbo39GIu0TMOiszq.jpg
# 7451     /xeEw3eLeSFmJgXZzmF2Efww0q3s.jpg
# 10191    /ygGmAO60t8GyqUo9xYeYxSZAR3b.jpg
# 11544    /d73UqZWyw3MUMpeaFcENgLZ2kWS.jpg
# 82702    /d13Uj86LdbDLrfDoHR5aDOFYyJC.jpg
# 166428   /xvx4Yhf0DVH8G4LzNISpMfFBDy2.jpg
# 324544   /dDlfjR7gllmr8HTeN6rfrYhTdwX.jpg
# 447273   /xWWg47tTfparvjK0WJNX4xL8lW2.jpg
# 541671   /mKp4euM5Cv3m2U1Vmby3OGwcD5y.jpg
# 552524   /A89x10Eqt43bPFEWPpbraWwkaFr.jpg
# 574475   /6WxhEvFsauuACfv8HyoVX6mZKFj.jpg
# 575265   /z53D72EAOxGRqdr7KXXWp9dJiDe.jpg
# 589018   /qC6yrKvmIEnkFVjpp0U7u02SiDQ.jpg
# 666154   /tpZdjnoJ6Z3NsSxI6HjAIggrcEv.jpg
# ...
